# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset= pd.read_csv('data/titanic.csv')
dataset.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
dataset['Fare'].mean()
mn= np.mean(dataset['Fare'])

#dataset['Fare']= dataset['Fare'].fillna(dataset['Fare'].mean())
md =np.median(dataset['Fare'])
mod= dataset['Fare'].mode()[0]

# %%
a=sns.histplot(x='Fare', data=dataset, bins= [i for i in range(0, 81 , 10)])
a.axvline(mn, color='red', linestyle='-.', label='mean'),
a.axvline(md, color='blue', linestyle='-.', label='median')
a.axvline(mod, color='green', linestyle='-.', label='mode')
plt.legend()
#plt.plot([mn for i in range (0,300)], [i for i in range (0,300)], c='red')

# %% [markdown]
# #$$MEDIAN

# %%
dataset['Age']= dataset['Age'].fillna(dataset['Age'].mean())
np.median(dataset['Age'])
# Out:
# np.float64(29.69911764705882)

# %% [markdown]
# MODE

# %%
dataset['Fare'].mode()[0]
# Out:
# np.float64(8.05)

# %%
dataset['Fare'].value_counts()
# Out:
# Fare
# 8.0500     43
# 13.0000    42
# 7.8958     38
# 7.7500     34
# 26.0000    31
#            ..
# 13.8583     1
# 50.4958     1
# 5.0000      1
# 9.8458      1
# 10.5167     1
# Name: count, Length: 248, dtype: int64

# %% [markdown]
# Range

# %%
min_r=dataset['Age'].min()
max_r=dataset['Age'].max()
min_r, max_r
# Out:
# (np.float64(0.42), np.float64(80.0))

# %%
range= max_r- min_r
range
# Out:
# np.float64(79.58)

# %%
sec_a= np.array([75, 65, 73, 68, 72, 76])
sec_b= np.array([90, 47, 43, 96, 93, 51])
no= np.array([1,2,3,4,5,6])

# %%
plt.figure(figsize=(8,3))
plt.scatter(sec_a, no, label='Sec A')
plt.scatter(sec_b, no, color='red', label='Sec B')
plt.plot([70,70,70,70,70,70], no, c='blue', label='Mean')
plt.legend()
plt.show()

# %%
mean= np.mean(sec_a)
mean
# Out:
# np.float64(71.5)

# %%
sec_a-mean
# Out:
# array([ 3.5, -6.5,  1.5, -3.5,  0.5,  4.5])

# %%
np.abs(sec_a-mean)
# Out:
# array([3.5, 6.5, 1.5, 3.5, 0.5, 4.5])

# %%
np.sum(np.abs(sec_a-mean))/len(sec_a)
# Out:
# np.float64(3.3333333333333335)

# %% [markdown]
# # ***Covariance & corelation***

# %%
dataset2= pd.read_csv("data/tip.csv")
dataset2.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
dataset2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %%
data_corr= dataset2.select_dtypes(['float64', 'int64']).corr()

# %%
data_cov= dataset2.select_dtypes(['float64', 'int64']).cov()

# %%
plt.figure(figsize= (4,3))
sns.heatmap(data_corr, annot= True)
# Out:
# <Axes: >

# %%
plt.figure(figsize= (4,3))
sns.heatmap(data_corr, annot= True)
plt.show()

# %%
#new comm
#z testing example 2

# %%
from scipy.stats import norm

# Sample data (class scores)
sample_scores = [78, 82, 85, 72, 80, 77, 79, 84, 81, 76]
n = len(sample_scores)  # Sample size
sample_mean = np.mean(sample_scores)  # Sample mean

# Population parameters (known)
pop_mean = 75  # μ
pop_std = 10   # σ
# Out:
# np.float64(79.4)

# %%
# TTEST
from scipy.stats import ttest_rel

# Before and after training program
before = [60, 65, 70, 55, 62]
after = [65, 70, 75, 60, 68]

t_stat, p_value = ttest_rel(before, after)
print(f"t-statistic: {t_stat:.2f}, p-value: {p_value:.4f}")
# Out:
# t-statistic: -26.00, p-value: 0.0000
